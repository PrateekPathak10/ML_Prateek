# %% [markdown]
# ## Diabetes Prediction using DT Regressor

# %%
from sklearn.datasets import load_diabetes

# %%
datasets=load_diabetes()

# %%
print(datasets['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
import pandas as pd
df_diabetes=pd.DataFrame(datasets.data,columns=['age',
  'sex',
  'bmi',
  'bp',
  's1',
  's2',
  's3',
  's4',
  's5',
  's6'])
df_diabetes.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
X=df_diabetes
y=datasets['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=10)

# %%
X_train.head()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 249 -0.012780 -0.044642  0.060618  0.052858  0.047965  0.029375 -0.017629
# 389 -0.005515  0.050680  0.001339 -0.084856 -0.011201 -0.016658  0.048640
# 121  0.063504 -0.044642  0.017506  0.021872  0.008063  0.021546 -0.036038
# 195  0.027178  0.050680  0.025051  0.014987  0.025950  0.048477 -0.039719
# 69   0.016281 -0.044642 -0.046085 -0.005670 -0.075870 -0.061438 -0.013948
#
#            s4        s5        s6
# 249  0.034309  0.070207  0.007207
# 389 -0.039493 -0.041176 -0.088062
# 121  0.034309  0.019907  0.011349
# 195  0.034309  0.007838  0.023775
# 69  -0.039493 -0.051404  0.019633

# %%
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.197408  0.198359  0.394903  0.238375  0.192920 -0.128403
# sex  0.197408  1.000000  0.108261  0.221914  0.057674  0.180315 -0.379464
# bmi  0.198359  0.108261  1.000000  0.356324  0.226047  0.248146 -0.395021
# bp   0.394903  0.221914  0.356324  1.000000  0.238295  0.165632 -0.192505
# s1   0.238375  0.057674  0.226047  0.238295  1.000000  0.872781  0.006313
# s2   0.192920  0.180315  0.248146  0.165632  0.872781  1.000000 -0.265114
# s3  -0.128403 -0.379464 -0.395021 -0.192505  0.006313 -0.265114  1.000000
# s4   0.227110  0.324882  0.412826  0.249141  0.559626  0.684840 -0.754616
# s5   0.314151  0.150956  0.435505  0.420236  0.566312  0.325759 -0.370523
# s6   0.351570  0.193322  0.358273  0.368882  0.356280  0.315890 -0.297055
#
#            s4        s5        s6
# age  0.227110  0.314151  0.351570
# sex  0.324882  0.150956  0.193322
# bmi  0.412826  0.435505  0.358273
# bp   0.249141  0.420236  0.368882
# s1   0.559626  0.566312  0.356280
# s2   0.684840  0.325759  0.315890
# s3  -0.754616 -0.370523 -0.297055
# s4   1.000000  0.609983  0.436311
# s5   0.609983  1.000000  0.490970
# s6   0.436311  0.490970  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## Hyperparameter Tuning

# %%
param={
    'criterion':['squared_error','friedman_mse','absolute_error'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
}

# %%
param
# Out:
# {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
#  'splitter': ['best', 'random'],
#  'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(regressor,param_grid=param,cv=5,scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'random'}

# %%
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.2972396959993222
# 4446.836062360153
# 54.79207891957473

# %%
selectedmodel=DecisionTreeRegressor(criterion='squared_error',max_depth=5,max_features='sqrt',splitter='random')

# %%
selectedmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, max_features='sqrt', splitter='random')

# %%
##Visualize the Decision Tree
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selectedmodel,filled=True)
# Out:
# [Text(0.49278846153846156, 0.9166666666666666, 'x[6] <= 0.027\nsquared_error = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.25961538461538464, 0.75, 'x[9] <= 0.041\nsquared_error = 5791.396\nsamples = 237\nvalue = 167.363'),
#  Text(0.37620192307692313, 0.8333333333333333, 'True  '),
#  Text(0.15384615384615385, 0.5833333333333334, 'x[7] <= -0.026\nsquared_error = 5157.647\nsamples = 189\nvalue = 155.508'),
#  Text(0.07692307692307693, 0.4166666666666667, 'x[1] <= -0.014\nsquared_error = 3839.159\nsamples = 46\nvalue = 122.283'),
#  Text(0.038461538461538464, 0.25, 'x[2] <= 0.045\nsquared_error = 3587.09\nsamples = 30\nvalue = 129.1'),
#  Text(0.019230769230769232, 0.08333333333333333, 'squared_error = 3542.8\nsamples = 25\nvalue = 124.0'),
#  Text(0.057692307692307696, 0.08333333333333333, 'squared_error = 3028.24\nsamples = 5\nvalue = 154.6'),
#  Text(0.11538461538461539, 0.25, 'x[2] <= 0.026\nsquared_error = 4061.25\nsamples = 16\nvalue = 109.5'),
#  Text(0.09615384615384616, 0.08333333333333333, 'squared_error = 4155.204\nsamples = 14\nvalue = 105.714'),
#  Text(0.1346153846153846, 0.08333333333333333, 'squared_error = 2601.0\nsamples = 2\nvalue = 136.0'),
#  Text(0.23076923076923078, 0.4166666666666667, 'x[2] <= 0.019\nsquared_error = 5112.437\nsamples = 143\nvalue = 166.196'),
#  Text(0.19230769230769232, 0.25, 'x[0] <= 0.068\nsquared_error = 3827.166\nsamples = 90\nvalue = 143.033'),
#  Text(0.17307692307692307, 0.08333333333333333, 'squared_error = 3815.284\nsamples = 83\nvalue = 139.458'),
#  Text(0.21153846153846154, 0.08333333333333333, 'squared_error = 2019.102\nsamples = 7\nvalue = 185.429'),
#  Text(0.2692307692307692, 0.25, 'x[5] <= 0.047\nsquared_error = 4836.891\nsamples = 53\nvalue = 205.528'),
#  Text(0.25, 0.08333333333333333, 'squared_error = 4890.123\nsamples = 41\nvalue = 214.78'),
#  Text(0.28846153846153844, 0.08333333333333333, 'squared_error = 3363.243\nsamples = 12\nvalue = 173.917'),
#  Text(0.36538461538461536, 0.5833333333333334, 'x[4] <= -0.057\nsquared_error = 5554.498\nsamples = 48\nvalue = 214.042'),
#  Text(0.34615384615384615, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 124.0'),
#  Text(0.38461538461538464, 0.4166666666666667, 'x[2] <= 0.049\nsquared_error = 5496.509\nsamples = 47\nvalue = 215.957'),
#  Text(0.34615384615384615, 0.25, 'x[2] <= -0.013\nsquared_error = 5576.454\nsamples = 28\nvalue = 187.786'),
#  Text(0.3269230769230769, 0.08333333333333333, 'squared_error = 2694.446\nsamples = 11\nvalue = 147.909'),
#  Text(0.36538461538461536, 0.08333333333333333, 'squared_error = 5746.595\nsamples = 17\nvalue = 213.588'),
#  Text(0.4230769230769231, 0.25, 'x[6] <= -0.018\nsquared_error = 2485.512\nsamples = 19\nvalue = 257.474'),
#  Text(0.40384615384615385, 0.08333333333333333, 'squared_error = 2043.484\nsamples = 16\nvalue = 264.875'),
#  Text(0.4423076923076923, 0.08333333333333333, 'squared_error = 2992.667\nsamples = 3\nvalue = 218.0'),
#  Text(0.7259615384615384, 0.75, 'x[4] <= 0.034\nsquared_error = 2624.157\nsamples = 72\nvalue = 104.597'),
#  Text(0.609375, 0.8333333333333333, '  False'),
#  Text(0.6057692307692307, 0.5833333333333334, 'x[8] <= 0.041\nsquared_error = 2640.051\nsamples = 56\nvalue = 100.643'),
#  Text(0.5384615384615384, 0.4166666666666667, 'x[4] <= -0.022\nsquared_error = 1511.322\nsamples = 53\nvalue = 92.868'),
#  Text(0.5, 0.25, 'x[3] <= 0.016\nsquared_error = 1084.948\nsamples = 20\nvalue = 85.55'),
#  Text(0.4807692307692308, 0.08333333333333333, 'squared_error = 626.67\nsamples = 19\nvalue = 80.474'),
#  Text(0.5192307692307693, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.5769230769230769, 0.25, 'x[8] <= -0.009\nsquared_error = 1717.605\nsamples = 33\nvalue = 97.303'),
#  Text(0.5576923076923077, 0.08333333333333333, 'squared_error = 1341.846\nsamples = 26\nvalue = 92.0'),
#  Text(0.5961538461538461, 0.08333333333333333, 'squared_error = 2620.857\nsamples = 7\nvalue = 117.0'),
#  Text(0.6730769230769231, 0.4166666666666667, 'x[1] <= 0.012\nsquared_error = 2646.0\nsamples = 3\nvalue = 238.0'),
#  Text(0.6538461538461539, 0.25, 'x[5] <= -0.026\nsquared_error = 2450.25\nsamples = 2\nvalue = 215.5'),
#  Text(0.6346153846153846, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 265.0'),
#  Text(0.6730769230769231, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(0.6923076923076923, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[7] <= -0.034\nsquared_error = 2322.246\nsamples = 16\nvalue = 118.438'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[2] <= -0.019\nsquared_error = 546.0\nsamples = 7\nvalue = 95.0'),
#  Text(0.7307692307692307, 0.25, 'x[4] <= 0.052\nsquared_error = 345.188\nsamples = 4\nvalue = 87.25'),
#  Text(0.7115384615384616, 0.08333333333333333, 'squared_error = 53.556\nsamples = 3\nvalue = 97.333'),
#  Text(0.75, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.8076923076923077, 0.25, 'x[0] <= 0.058\nsquared_error = 626.889\nsamples = 3\nvalue = 105.333'),
#  Text(0.7884615384615384, 0.08333333333333333, 'squared_error = 156.25\nsamples = 2\nvalue = 121.5'),
#  Text(0.8269230769230769, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.9230769230769231, 0.4166666666666667, 'x[2] <= -0.0\nsquared_error = 2944.222\nsamples = 9\nvalue = 136.667'),
#  Text(0.8846153846153846, 0.25, 'x[8] <= 0.081\nsquared_error = 1188.857\nsamples = 7\nvalue = 118.0'),
#  Text(0.8653846153846154, 0.08333333333333333, 'squared_error = 1234.556\nsamples = 6\nvalue = 122.667'),
#  Text(0.9038461538461539, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.9615384615384616, 0.25, 'x[0] <= 0.013\nsquared_error = 3600.0\nsamples = 2\nvalue = 202.0'),
#  Text(0.9423076923076923, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.9807692307692307, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 262.0')]
